# %% [markdown]
# ### Import packages

# %%
import pandas as pd

# %% [markdown]
# ### Load responses

# %%
df = pd.read_csv('irony_annotation_study_responses.csv')

# %%
df[:1]
# Out:
#              Timestamp Wie alt bist du? Wie oft nutzt du Reddit?  \
# 0  18/03/2026 14:32:07            18-24                   Selten
#
#    Wie gut schätzt du dich selbst ein Ironie im Alltag erkennen zu können?  \
# 0                                                  5
#
#   Wie gut kennst du r/de?  \
# 0  Kenne ich, lese selten
#
#    KOMMENTAR #1\n\nTHREAD: Mehrheit sieht ältere im Vorteil - nicht einmal ein Drittel der jungen glaubt an faire Rente\n\nKOMMENTAR: Solange alle ihre Tiefkühlpizza und RTL haben ist doch alles super!\n\nWie ironisch ist dieser Kommentar?  \
# 0                                                  5
#
#    Wie sicher bist du dir bei dieser Einschätzung?  \
# 0                                                5
#
#    KOMMENTAR #2\n\nTHREAD: Mehrheit sieht ältere im Vorteil - nicht einmal ein Drittel der jungen glaubt an faire Rente\n\nKOMMENTAR: Ich bin schockiert.\n\nWie ironisch ist dieser Kommentar?  \
# ...
